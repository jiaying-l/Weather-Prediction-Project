# %% [markdown]
# <a href="https://colab.research.google.com/github/jiaying-l/Weather-Prediction-Project/blob/main/CS171_ProjectCode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project - Identifying Bone Fractures

# %% [markdown]
# Group Members: Andranik Avagyan, Jiaying Li, Y-nha Nguyen
# Professor Tahereh Arabghalizi
# CS 171, Section 1
# Last updated: 18 April, 2026

# %% [markdown]
# In medical emergencies, bone fractures are one of the most common injuries that require proper care. However, X-rays can often be misread or missed, delaying treatment for patients. To explore this issue, this project will use CNN-based image classification to detect fractures using this [Bone Fracture Dataset](https://www.kaggle.com/datasets/osamajalilhassan/bone-fracture-dataset/data) from Kaggle.

# %% [markdown]
# ##Libraries Used
